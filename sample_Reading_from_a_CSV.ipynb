# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#pd.set_option('display.mpl_style','default')
plt.rcParams['figure.figsize']=(15,5)

# %%
broken_df= pd.read_csv("/Users/pxchapp/datasets/bikes.csv",sep=";")

# %%
# ?pd.read_csv

# %%
broken_df[:3]
# Out:
#          Date  Berri 1  Br?beuf (donn?es non disponibles)  \
# 0  01/01/2012       35                                NaN
# 1  02/01/2012       83                                NaN
# 2  03/01/2012      135                                NaN
#
#    C?te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
#
#    Rachel1  St-Urbain (donn?es non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# 2       58                                  NaN

# %% [markdown]
# ## load the data with changing the
# ###   1. line seperator
# ###   2. change the language
# ###   3. make column as date
# ###   4. make date as the index, basically a time series data

# %%
broken_df=pd.read_csv("/Users/pxchapp/datasets/bikes.csv",
                       sep=";",
                       encoding="latin1",
                       parse_dates=["Date"],
                       dayfirst=True,
                       index_col="Date")

# %%
broken_df.head()
# Out:
#             Berri 1  Br?beuf (donn?es non disponibles)  C?te-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
# 2012-01-04      144                                NaN                      1
# 2012-01-05      197                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-01             38             51       26            10       16
# 2012-01-02             68            153       53             6       43
# 2012-01-03            104            248       89             3       58
# 2012-01-04            116            318      111             8       61
# 2012-01-05            124            330       97            13       95
#
# ...

# %%
len(broken_df.index)
# Out:
# 310

# %% [markdown]
# ### select data by a column name

# %%
broken_df["Berri 1"]
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
# 2012-01-06     146
# 2012-01-07      98
# 2012-01-08      95
# 2012-01-09     244
# 2012-01-10     397
# 2012-01-11     273
# 2012-01-12     157
# 2012-01-13      75
# 2012-01-14      32
# 2012-01-15      54
# 2012-01-16     168
# 2012-01-17     155
# 2012-01-18     139
# 2012-01-19     191
# 2012-01-20     161
# 2012-01-21      53
# 2012-01-22      71
# 2012-01-23     210
# 2012-01-24     299
# 2012-01-25     334
# 2012-01-26     306
# 2012-01-27      91
# 2012-01-28      80
# 2012-01-29      87
# 2012-01-30     219
#               ...
# 2012-10-07    1580
# 2012-10-08    1854
# 2012-10-09    4787
# 2012-10-10    3115
# 2012-10-11    3746
# 2012-10-12    3169
# 2012-10-13    1783
# 2012-10-14     587
# 2012-10-15    3292
# 2012-10-16    3739
# 2012-10-17    4098
# 2012-10-18    4671
# 2012-10-19    1313
# 2012-10-20    2011
# 2012-10-21    1277
# 2012-10-22    3650
# ...

# %% [markdown]
# ### to plot

# %%
broken_df["Berri 1"].plot()

# %% [markdown]
# ### to plot all column data

# %%
broken_df.plot()
#plt.show()

# %%
plt.show()
